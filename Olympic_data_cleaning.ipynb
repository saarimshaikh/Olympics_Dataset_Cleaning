# %% [markdown]
# <a href="https://colab.research.google.com/github/saarimshaikh/Olympics_Dataset_Cleaning/blob/main/Olympic_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saarimshaikh/Olympics_Dataset_Cleaning.git
# Out:
# Cloning into 'Olympics_Dataset_Cleaning'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 16 (delta 1), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (16/16), 20.16 MiB | 15.71 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
import pandas as pd

# %%
bios = pd.read_csv('./Olympics-Dataset/athletes/bios.csv')

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %%
df = bios.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 17.8+ MB

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %%
df['name'] = df['Used name'].str.replace("•", " ")

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name
# 0         NaN           NaN        NaN  Jean-François Blanchy
# 1         NaN           NaN        NaN         Arnaud Boetsch
# 2         NaN           NaN        NaN           Jean Borotra
# 3         NaN           NaN        NaN        Jacques Brugnon
# 4         NaN           NaN        NaN           Albert Canet

# %%
# split the Measurements column into height and weight columns

df[['Height_cm', 'Weight_kg']] = df['Measurements'].str.split('/', expand = True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name Height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy       NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch   183 cm
# 2         NaN           NaN        NaN           Jean Borotra   183 cm
# 3         NaN           NaN        NaN        Jacques Brugnon   168 cm
# 4         NaN           NaN        NaN           Albert Canet       NaN
#
#   Weight_kg
# 0       NaN
# 1     76 kg
# 2     76 kg
# 3     64 kg
# 4       NaN

# %%
#check to make sure all values have the '/'
df[~df['Measurements'].str.contains('/', na = False) & df['Measurements'].notna()]
# Out:
#                                           Roles     Sex  \
# 87      Competed in Olympic Games • Non-starter    Male
# 105                   Competed in Olympic Games    Male
# 165                   Competed in Olympic Games  Female
# 242                   Competed in Olympic Games  Female
# 243                   Competed in Olympic Games  Female
# ...                                         ...     ...
# 145058                Competed in Olympic Games    Male
# 145096                Competed in Olympic Games  Female
# 145163                Competed in Olympic Games    Male
# 145494                Competed in Olympic Games    Male
# 145498                Competed in Olympic Games    Male
#
#                                       Full name             Used name  \
# 87               Hugh Lawrence "Laurie"•Doherty        Laurie•Doherty
# 105                      Harold Segerson•Mahony         Harold•Mahony
# 165                       Patricia Akosua•Offel        Patricia•Offel
# 242     Lucia Francisca "Susy"•Susanti Haditono          Susy•Susanti
# 243                                  Lili•Tampi            Lili•Tampi
# ...                                         ...                   ...
# 145058          Daniil Ruslanovich•Serokhvostov   Daniil•Serokhvostov
# 145096               Kamila Valeryevna•Valiyeva       Kamila•Valiyeva
# 145163                     Daniel Andrei•Cacina  Daniel Andrei•Cacina
# 145494                   George Fletcher•Wright         George•Wright
# 145498                           André•Foussard        André•Foussard
#
#                                                      Born  \
# 87             8 October 1875 in Wimbledon, England (GBR)
# 105         13 February 1867 in Edinburgh, Scotland (GBR)
# 165                                      19 December 1971
# 242     11 February 1971 in Tasikmalaya, Jawa Barat (INA)
# 243          19 May 1970 in Tasikmalaya, Jawa Barat (INA)
# ...                                                   ...
# 145058          4 April 1999 in Barnaul, Altay Kray (RUS)
# 145096  26 April 2006 in Kazan, Respublika Tatarstan (...
# 145163            17 October 2001 in Brașov, Brașov (ROU)
# 145494             21 July 1890 in Toronto, Ontario (CAN)
# 145498            19 May 1899 in Niort, Deux-Sèvres (FRA)
#
#                                                      Died            NOC  \
# 87           21 August 1919 in Broadstairs, England (GBR)  Great Britain
# 105     27 June 1905 in between Glencar and Killorgin,...  Great Britain
# 165                                                   NaN          Ghana
# 242                                                   NaN      Indonesia
# 243                                                   NaN      Indonesia
# ...                                                   ...            ...
# 145058                                                NaN            ROC
# 145096                                                NaN            ROC
# 145163                                                NaN        Romania
# 145494   28 January 1973 in Los Angeles, California (USA)         Canada
# 145498          18 March 1986 in Niort, Deux-Sèvres (FRA)         France
#
#         athlete_id Measurements  \
# 87              88       178 cm
# 105            106       191 cm
# 165            166       120 kg
# 242            243       161 cm
# 243            244       161 cm
# ...            ...          ...
# 145058      148770       168 cm
# 145096      148809       160 cm
# 145163      148880       190 cm
# 145494      149221       183 cm
# 145498      149225       166 cm
#
#                                              Affiliations Nick/petnames  \
# 87      All England Lawn Tennis and Croquet Club, Wimb...     Little Do
# 105            Fitzwilliam Lawn Tennis Club, Dublin (IRL)           NaN
# 165                                                   NaN           NaN
# 242                              Jaya Raya, Jakarta (INA)           NaN
# 243                                                   NaN           NaN
# ...                                                   ...           ...
# 145058                                                NaN           NaN
# 145096                                                NaN           NaN
# 145163                                                NaN           NaN
# 145494                Argonaut Rowing Club, Toronto (CAN)           NaN
# 145498                        Beauvoisine FC, Rouen (FRA)           NaN
#
#        Title(s)          Other names Nationality  \
# 87          NaN                  NaN         NaN
# 105         NaN                  NaN     Ireland
# 165         NaN                  NaN         NaN
# 242         NaN  Wang Lianxiang, 王蓮香         NaN
# 243         NaN                  NaN         NaN
# ...         ...                  ...         ...
# 145058      NaN                  NaN         NaN
# 145096      NaN                  NaN         NaN
# 145163      NaN                  NaN         NaN
# 145494      NaN                  NaN         NaN
# 145498      NaN                  NaN         NaN
#
#                         Original name Name order                  name  \
# 87                                NaN        NaN        Laurie Doherty
# 105                               NaN        NaN         Harold Mahony
# 165                               NaN        NaN        Patricia Offel
# 242                               NaN        NaN          Susy Susanti
# 243                               NaN        NaN            Lili Tampi
# ...                               ...        ...                   ...
# 145058  Даниил Русланович•Серохвостов        NaN   Daniil Serokhvostov
# 145096      Камила Валерьевна•Валиева        NaN       Kamila Valiyeva
# 145163                            NaN        NaN  Daniel Andrei Cacina
# 145494                            NaN        NaN         George Wright
# 145498                            NaN        NaN        André Foussard
#
#        Height_cm Weight_kg
# 87        178 cm      None
# 105       191 cm      None
# 165       120 kg      None
# 242       161 cm      None
# 243       161 cm      None
# ...          ...       ...
# 145058    168 cm      None
# 145096    160 cm      None
# 145163    190 cm      None
# 145494    183 cm      None
# 145498    166 cm      None
#
# [4805 rows x 19 columns]

# %%
#creating toy data to check missing cases

small_data = pd.DataFrame(['183 cm', '180 cm / 150 kg', '190 cm / 80 kg', '100 kg'], columns=["Measurements"])
small_data[['Height_cm', 'Weight_kg']] = small_data['Measurements'].str.split('/', expand=True)
small_data['Weight_kg'].fillna(small_data['Height_cm'], inplace=True)

small_data['Height_cm'] = pd.to_numeric(small_data['Height_cm'].str.strip(' cm'), errors = 'coerce')
small_data['Weight_kg'] = pd.to_numeric(small_data['Weight_kg'].str.strip(' kg'), errors = 'coerce')

small_data.head()
# Out:
#       Measurements  Height_cm  Weight_kg
# 0           183 cm      183.0        NaN
# 1  180 cm / 150 kg      180.0      150.0
# 2   190 cm / 80 kg      190.0       80.0
# 3           100 kg        NaN      100.0

# %%
# Split the Measurements column into height and weight columns
# Cleaning the original data after testing it on the copy data named "small_data"

df[['Height_cm', 'Weight_kg']] = df['Measurements'].str.split('/', expand=True)

# %%
# Get rid of " cm" and the " kg" from our new columns
df['Height_cm'] = pd.to_numeric(df['Height_cm'].str.strip(' cm'), errors='coerce')
df['Weight_kg'] = pd.to_numeric(df['Weight_kg'].str.strip(' kg'), errors='coerce')

# %%
df.sort_values('Height_cm', ascending=False)
# Out:
#                                     Roles     Sex  \
# 89070   Competed in Olympic Games • Other    Male
# 5781            Competed in Olympic Games    Male
# 6978            Competed in Olympic Games    Male
# 89075           Competed in Olympic Games    Male
# 120266          Competed in Olympic Games    Male
# ...                                   ...     ...
# 145490          Competed in Olympic Games    Male
# 145491          Competed in Olympic Games    Male
# 145492          Competed in Olympic Games    Male
# 145493          Competed in Olympic Games  Female
# 145499        Non-starter • Administrator    Male
#
#                              Full name              Used name  \
# 89070                         Yao•Ming               Yao•Ming
# 5781     Thomas Loren "Tommy"•Burleson         Tommy•Burleson
# 6978             Arvydas Romas•Sabonis        Arvydas•Sabonis
# 89075         Roberto•Dueñas Hernández         Roberto•Dueñas
# 120266                    Zhang•Zhaoxu           Zhang•Zhaoxu
# ...                                ...                    ...
# 145490                     Sin•Ye-Chan            Sin•Ye-Chan
# 145491                   Matthew•Wepke          Matthew•Wepke
# 145492  Carlos•García-Ordóñez Montalvo  Carlos•García-Ordóñez
# 145493    Landysh Ilsurovna•Falyakhova     Landysh•Falyakhova
# 145499   William Berge "Bill"•Phillips          Bill•Phillips
#
#                                                      Born  \
# 89070   12 September 1980 in Xuhui District, Shanghai ...
# 5781    24 February 1952 in Crossnore, North Carolina ...
# 6978             19 December 1964 in Kaunas, Kaunas (LTU)
# 89075             1 November 1975 in Madrid, Madrid (ESP)
# 120266        18 November 1987 in Binzhou, Shandong (CHN)
# ...                                                   ...
# 145490                                       13 June 1995
# 145491                                    5 December 1989
# 145492  24 April 1927 in La Habana (Havana), Ciudad de...
# 145493  31 August 1998 in Dva Polya Artash, Respublika...
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                     Died  \
# 89070                                                NaN
# 5781                                                 NaN
# 6978                                                 NaN
# 89075                                                NaN
# 120266                                               NaN
# ...                                                  ...
# 145490                                               NaN
# 145491                                               NaN
# 145492          24 November 2019 in Miami, Florida (USA)
# 145493                                               NaN
# 145499  20 October 2003 in Sydney, New South Wales (AUS)
#
#                                NOC  athlete_id     Measurements  \
# 89070   People's Republic of China       89782  226 cm / 141 kg
# 5781                 United States        5804  223 cm / 102 kg
# 6978        Lithuania Soviet Union        7013  223 cm / 122 kg
# 89075                        Spain       89787  221 cm / 137 kg
# 120266  People's Republic of China      122147  221 cm / 110 kg
# ...                            ...         ...              ...
# 145490           Republic of Korea      149217              NaN
# 145491                     Jamaica      149218              NaN
# 145492                        Cuba      149219              NaN
# 145493                         ROC      149220              NaN
# 145499                   Australia      149814              NaN
#
#                                              Affiliations Nick/petnames  \
# 89070   Shanghai Sharks, Shanghai (CHN) / Houston Rock...           NaN
# 5781                     NC State Wolfpack, Raleigh (USA)           NaN
# 6978    Žalgiris Kaunas, Kaunas (LTU) / Real Madrid, M...         Sabas
# 89075                       FC Barcelona, Barcelona (ESP)           NaN
# 120266                    Shanghai Sharks, Shanghai (CHN)           NaN
# ...                                                   ...           ...
# 145490                                                NaN           NaN
# 145491                                                NaN           NaN
# 145492                                                NaN           NaN
# 145493        SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)           NaN
# 145499                                                NaN           NaN
#
#        Title(s)                                   Other names Nationality  \
# 89070       NaN                                           NaN         NaN
# 5781        NaN                                           NaN         NaN
# 6978        NaN  Arvidas Romas Sabonis, Арвидас Ромас Сабонис   Lithuania
# 89075       NaN                                           NaN         NaN
# 120266      NaN                                           NaN         NaN
# ...         ...                                           ...         ...
# 145490      NaN                                  Shin Ye-Chan         NaN
# 145491      NaN                                           NaN         NaN
# 145492      NaN                                           NaN         NaN
# 145493      NaN                                           NaN         NaN
# 145499      NaN                                           NaN         NaN
#
#                      Original name Name order                   name  \
# 89070                          姚•明   Oriental               Yao Ming
# 5781                           NaN        NaN         Tommy Burleson
# 6978                           NaN        NaN        Arvydas Sabonis
# 89075                          NaN        NaN         Roberto Dueñas
# 120266                        张•兆旭   Oriental           Zhang Zhaoxu
# ...                            ...        ...                    ...
# 145490                        신•예찬   Oriental            Sin Ye-Chan
# 145491                         NaN        NaN          Matthew Wepke
# 145492                         NaN        NaN  Carlos García-Ordóñez
# 145493  Ландыш Ильсуровна•Фаляхова        NaN     Landysh Falyakhova
# 145499                         NaN        NaN          Bill Phillips
#
#         Height_cm  Weight_kg
# 89070       226.0      141.0
# 5781        223.0      102.0
# 6978        223.0      122.0
# 89075       221.0      137.0
# 120266      221.0      110.0
# ...           ...        ...
# 145490        NaN        NaN
# 145491        NaN        NaN
# 145492        NaN        NaN
# 145493        NaN        NaN
# 145499        NaN        NaN
#
# [145500 rows x 19 columns]

# %%
# Parse out dates from 'Born' and 'Died' columns
date_pattern = r'(\d+ \w+ \d{4}|\d{4})'
df['born_date'] = df['Born'].str.extract(date_pattern)
df['born_year'] = df['Born'].str.extract(r'(\d{4})')

df['born_date'] = pd.to_datetime(df['born_date'], format="mixed", errors='coerce')
df['born_year'] = pd.to_numeric(df['born_year'])

df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], format="mixed", errors='coerce')

# %%
# Get city, region, and country from Born column
location_pattern = r'in ([\w\s()-]+), ([\w\s-]+) \((\w+)\)'
df['Born'].str.extract(location_pattern)
# Out:
#                       0                     1    2
# 0              Bordeaux               Gironde  FRA
# 1                Meulan              Yvelines  FRA
# 2              Biarritz  Pyrénées-Atlantiques  FRA
# 3           Paris VIIIe                 Paris  FRA
# 4            Wandsworth               England  GBR
# ...                 ...                   ...  ...
# 145495            Serov            Sverdlovsk  RUS
# 145496  Moskva (Moscow)                Moskva  RUS
# 145497           Kotlas           Arkhangelsk  RUS
# 145498            Niort           Deux-Sèvres  FRA
# 145499     Dulwich Hill       New South Wales  AUS
#
# [145500 rows x 3 columns]

# %%
df[['born_city','born_region','born_country']] = df['Born'].str.extract(location_pattern, expand=True)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df.value_counts('born_city', ascending=False).head(25)
# Out:
# born_city
# Budapest                          1378
# Moskva (Moscow)                    883
# Oslo                               708
# Stockholm                          629
# Praha (Prague)                     600
# Toronto                            579
# Wien (Vienna)                      547
# Buenos Aires                       538
# København (Copenhagen)             523
# Sydney                             497
# Montréal                           468
# Berlin                             467
# Ciudad de México (Mexico City)     455
# Helsinki                           439
# Rio de Janeiro                     433
# Amsterdam                          429
# Barcelona                          425
# Melbourne                          417
# New York                           416
# Seoul                              405
# São Paulo                          393
# London                             386
# Madrid                             379
# Athina (Athens)                    348
# Roma                               344
# Name: count, dtype: int64

# %%
# Remove any unneccessary columns
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'name', 'Height_cm', 'Weight_kg', 'born_date', 'born_year', 'died_date',
#        'born_city', 'born_region', 'born_country'],
#       dtype='object')

# %%
columns_to_keep = ['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
                   'born_country', 'NOC', 'Height_cm', 'Weight_kg', 'died_date']

df_clean = df[columns_to_keep]

# %%
df_clean.to_csv('./Olympics-Dataset/clean-data/bios.csv', index=False)

# %% [markdown]
# Cleaning results data

# %%
import pandas as pd
results = pd.read_csv('./Olympics-Dataset/results/results.csv')
# Out:
# <ipython-input-42-a1cfcb206ca2>:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv('./Olympics-Dataset/results/results.csv')

# %%
df = results.copy()

# %%
df.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN

# %% [markdown]
# Cleaning to-do:
#
# Split year and type from games
#
# split out tied column from position
#
# make non-numeric POSs NAN in Pos
#
# drop unnamed column
#
# Reorder columns

# %%
df['place'] = df['Pos'].str.extract(r'(\d+)')
df['tied'] = df['Pos'].str.contains("=")

# %%
df['medal_new'] = df["Medal"].map({"Bronze": 3, "Silver": 2, "Gold":1})

# %%
df[['year', 'type']] = df['Games'].str.extract(r'(\d{4}) (Summer|Winter)', expand=True)

# %%
df.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7  \
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
#
#   place   tied  medal_new  year    type
# 0    17   True        NaN  1912  Summer
# 1   NaN  False        NaN  1912  Summer
# 2    32   True        NaN  1920  Summer
# 3     8   True        NaN  1920  Summer
# 4     4  False        NaN  1920  Summer

# %%
df['year'] = pd.to_numeric(df['year'])

# %%
df.sort_values('year', ascending=False)
# Out:
#                           Games                             Event      Team  \
# 308407     2022 Winter Olympics           Slalom, Women (Olympic)       NaN
# 274176     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274171     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274168     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274149     2022 Winter Olympics              Four, Open (Olympic)  Latvia 1
# ...                         ...                               ...       ...
# 203177  1906 Intercalated Games  Sabre, Individual, Men (Olympic)       NaN
# 203178  1906 Intercalated Games        Sabre, Team, Men (Olympic)   Hungary
# 217586  1906 Intercalated Games      Football, Men (Intercalated)    Athens
# 217587  1906 Intercalated Games      Football, Men (Intercalated)    Athens
# 271490  1906 Intercalated Games      Platform, Men (Intercalated)       NaN
#
#          Pos Medal                    As  athlete_id  NOC  \
# 308407  24.0   NaN  Charlotta Säfvenberg      148986  NaN
# 274176  11.0   NaN        Ronalds Ķēniņš      128130  LAT
# 274171   DNS   NaN   Kristers Gudļevskis      128127  LAT
# 274168    11   NaN       Ralfs Freibergs      128125  LAT
# 274149   5.0   NaN     Oskars Ķibermanis      128118  LAT
# ...      ...   ...                   ...         ...  ...
# 203177     5   NaN       Lóránt Mészáros       95189  HUN
# 203178     4   NaN       Lóránt Mészáros       95189  HUN
# 217586    AC   NaN       Georgios Pantos      100811  GRE
# 217587    AC   NaN  Alexandros Kalafatis      100812  GRE
# 271490  13.0   NaN      Wilhelm Lindgren      127259  SWE
#
#                      Discipline Nationality  Unnamed: 7 place   tied  \
# 308407                      NaN         NaN         NaN    24  False
# 274176  Ice Hockey (Ice Hockey)         NaN         NaN    11  False
# 274171  Ice Hockey (Ice Hockey)         NaN         NaN   NaN  False
# 274168  Ice Hockey (Ice Hockey)         NaN         NaN    11  False
# 274149    Bobsleigh (Bobsleigh)         NaN         NaN     5  False
# ...                         ...         ...         ...   ...    ...
# 203177                  Fencing         NaN         NaN     5  False
# 203178                  Fencing         NaN         NaN     4  False
# 217586      Football (Football)         NaN         NaN   NaN  False
# 217587      Football (Football)         NaN         NaN   NaN  False
# 271490        Diving (Aquatics)         NaN         NaN    13  False
#
#         medal_new    year    type
# 308407        NaN  2022.0  Winter
# 274176        NaN  2022.0  Winter
# 274171        NaN  2022.0  Winter
# 274168        NaN  2022.0  Winter
# 274149        NaN  2022.0  Winter
# ...           ...     ...     ...
# 203177        NaN     NaN     NaN
# 203178        NaN     NaN     NaN
# 217586        NaN     NaN     NaN
# 217587        NaN     NaN     NaN
# 271490        NaN     NaN     NaN
#
# [308408 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Games', 'Event', 'Team', 'Pos', 'Medal', 'As', 'athlete_id', 'NOC',
#        'Discipline', 'Nationality', 'Unnamed: 7', 'place', 'tied', 'medal_new',
#        'year', 'type'],
#       dtype='object')

# %%
columns_to_keep = ['year','type','Discipline', 'Event', 'As', 'athlete_id', 'NOC', 'Team', 'place', 'tied', 'Medal']
df = df[columns_to_keep]

# %%
# !pip install  pyjanitor
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.27.0-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (8.4.0)
# Collecting pandas-flavor (from pyjanitor)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.11.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2.0.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2023.7.0)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->pyjanitor) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2024.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pandas-flavor->pyjanitor) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-flavor->pyjanitor) (1.16.0)
# Installing collected packages: pandas-flavor, pyjanitor
# Successfully installed pandas-flavor-0.6.0 pyjanitor-0.27.0

# %%
import janitor

# %%
df = df.clean_names()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.to_csv('./Olympics-Dataset/clean-data/results.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['place'] = pd.to_numeric(df['place'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['tied'] = df['tied'].astype(bool)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
df.to_csv('./Olympics-Dataset/clean-data/results.csv',index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv('./Olympics-Dataset/clean-data/bios.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  Height_cm  Weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
